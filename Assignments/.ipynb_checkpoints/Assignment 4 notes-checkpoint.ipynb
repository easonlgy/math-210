# %% [markdown]
# # Assignment 4
#
# ## 1.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def curve(A,B,C):
    t = np.linspace(0,2*np.pi,1000)
    x = A*(np.sin(t))**3
    y = B*np.cos(t) - C*np.cos(2*t)
    plt.plot(x,y)
    plt.axis('equal')

# %%
curve(13,6,4)

# %% [markdown]
# ## 2.

# %%
def power_series(a,x):
    k = np.arange(0,np.size(a))
    ps = np.sum(a * (x**k))
    return ps

# %%
power_series(np.ones(100),0.5)
# Out:
# 2.0

# %%
from scipy.special import factorial

# %%
power_series(1 / factorial(np.arange(0,100)),1)
# Out:
# 2.7182818284590451

# %% [markdown]
# ## 3.
#
# ### (a)
# $$
# f_{triangle} (t) = \frac {8} {\pi^2} \sum_{k=0}^{\infty} (-1)^k \frac {\sin(2\pi(2k+1)t)}{(2k+1)^2}
# $$

# %% [markdown]
# ### (b)

# %%
def triangle_wave(N,interval):
    f1 = 0
    for k in range(0,N+1):
        t = np.linspace(0,N,1000)
        f1 = f1 + (8 / (np.pi)**2) *  (((-1)**k) * (np.sin(2*np.pi * (2*k+1)*t)) / ((2*k + 1)**2))
    plt.plot(t,f1), plt.xlim(interval), plt.ylim([-2,2]), plt.grid('on')

# %%
triangle_wave(3,[0,3])

# %%
t = np.arange(0,3+1,1)
t
# Out:
# array([0, 1, 2, 3])

# %%
x = np.linspace(0,3,3)
x
# Out:
# array([ 0. ,  1.5,  3. ])

# %% [markdown]
# ## 4.
#
# ### (a)
#
# $$
# f_{sawtooth}(t) = \frac{2}{\pi} \sum_{k=1}^{\infty} \frac {(-1)^{k+1} \sin(2\pi kt)}{k}
# $$

# %% [markdown]
# ### (b)

# %%
def sawtooth_waves(n,m,T):
    plt.figure(figsize=(2*m,2*n))
    N = n*m
    f1 = 0
    for k in range(1,N+1):
        plt.subplot(n,m,k)
        t = np.linspace(0,T,1000)
        f1 = f1 + ((2 / np.pi) * (((-1)**(k+1) * np.sin(2*np.pi*k*t)) / k))
        plt.plot(t,f1)
        plt.grid('on'), plt.title('N =' + str(k))
        plt.tight_layout()

# %%
sawtooth_waves(2,4,2)

# %% [markdown]
# ## 5.
#
# ### (a)
#
# $$
# \zeta (s) = \sum_{n=1}^{\infty} \frac{1}{n^s} = \prod_{p \ prime} \frac{1}{1-p^{-s}} = \frac{1}{1-2^{-s}} \cdot \frac{1}{1-3^{-s}} \cdot \frac{1}{1-5^{-s}} \cdot \frac{1}{1-7^{-s}} \cdots \frac{1}{1-p^{-s}} \cdots
# $$

# %% [markdown]
# ### (b)

# %%
def euler_product(s,N):
    if N == 2:
        product = 1 / (1 - 2**(-s))
        return product
    elif N > 2:
        product = 1 
        for d in range(2,N+1):
            for n in range(2,d):
                if d % n == 0:a
                    break
            else:
                product1 = product * (1 / (1 - d**(-s)))
                product = product1 
        return product
    else:
        product = 1
        return product

# %%
euler_product(4,1)
# Out:
# 1

# %%
def is_prime(N):
    "determine whether or not N is a prime number."
    
    if N <= 1:
        return False
    for d in range(2,N): 
        if N % d == 0:
            return False
    return True

# %%
1 / (1 - 2**(-4))
# Out:
# 1.0666666666666667

# %%
np.pi**4/90
# Out:
# 1.082323233711138

# %% [markdown]
# ## 6.

# %%
def slope_field(f,tlims,ylims,grid_step):
    slope = 
    t = np.linspace(-100,100,1000)
    s = slope * (t-ti) + yi
    plt.plot(t,s)
    plt.tlim(tlims), plt.ylim(ylims)

# %%
def f(t,y):
    return y**2-t**2

# %%
slope_field(f,[-3,3],[-2,2],0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-cd7d4c03fe82> in <module>()
# ----> 1 slope_field(f,[-3,3],[-2,2],0.2)
#
# <ipython-input-3-a8e6e05aff2d> in slope_field(f, tlims, ylims, grid_step)
#       1 def slope_field(f,tlims,ylims,grid_step):
#       2     t = np.linspace(-100,100,1000)
# ----> 3     s = slope * (t-ti) + yi
#       4     plt.plot(t,s)
#       5     plt.tlim(tlims), plt.ylim(ylims)
#
# NameError: name 'slope' is not defined

# %%
def slope_field1(f,tlims,ylims,grid_step):
    t = np.linspace(-10,10,100)
    y = np.linspace(-10,10,100)


    for j in t:
        for k in y:
            slope = f(j,k)
            angle = np.arctan(slope)
            d = np.cos(angle)
            L = grid_step/2.5 * d
            domain = np.linspace(j-L,j+L,2)
            z = slope*(domain-j)+k
                
            plt.plot(domain,z,'b')
            plt.xlim(tlims), plt.ylim(ylims)

# %%
def f(t,y):
    return y**2-t**2

# %%
slope_field1(f,[-3,3],[-2,2],0.2)
