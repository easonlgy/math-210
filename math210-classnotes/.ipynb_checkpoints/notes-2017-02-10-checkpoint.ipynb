# %% [markdown]
# # MATH 210 Introduction to Mathematical Computing
#
# ## February 10, 2017
#
# 1. More 3D plotting
# 2. Miscellaneous advanced topics
#   * Functions with keyword arguments
#   * List comprehensions with if/else
# 3. Exercises

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## 1. More 3D plotting
#
# ### Example
#
# Let's plot $z = x^2 - y^2$ for $x,y \in [-2,2]$.

# %%
plt.figure()
ax = plt.axes(projection='3d')

x = np.linspace(-2,2,50)
y = np.linspace(-2,2,50)
X, Y = np.meshgrid(x,y)
Z = X**2 - Y**2

ax.contour(X,Y,Z)

# %%
plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(X,Y,Z)

# %%
plt.figure()
ax = plt.axes(projection='3d')

ax.plot_wireframe(X,Y,Z)

# %% [markdown]
# ### Example
#
# Let's plot the Trefoil knot in 3D:
#
# $$
# x = \sin(t) + 2 \sin(2t) \ \ , \ \ y = \cos(t) - 2 \cos(2t) \ \ , \ \ z = -\sin(3t)
# $$
# for $t \in [0,2\pi]$

# %%
plt.figure()
ax = plt.axes(projection='3d')

t = np.linspace(0,2*np.pi,100)

x = np.sin(t) + 2*np.sin(2*t)
y = np.cos(t) - 2*np.cos(2*t)
z = -np.sin(3*t)

# ax.view_init(90,0)
ax.plot(x,y,z)

# %% [markdown]
# ### Example
#
# Let's plot a 3D torus.

# %%
plt.figure()
ax = plt.axes(projection='3d')

R = 3
r = 1
theta = np.linspace(0,2*np.pi,50)
phi = np.linspace(0,2*np.pi,50)

PHI, THETA = np.meshgrid(phi,theta)

X = (R + r*np.cos(THETA))*np.cos(PHI)
Y = (R + r*np.cos(THETA))*np.sin(PHI)
Z = r * np.sin(THETA)

ax.view_init(60,30)
ax.plot_wireframe(X,Y,Z)

# %%
plt.figure()
ax = plt.axes(projection='3d')

R = 3
r = 1
theta = np.linspace(0,4*np.pi,50)
phi = np.linspace(0,4*np.pi,50)

PHI, THETA = np.meshgrid(phi,theta)

X = (R + r*np.cos(THETA))*np.cos(0.5*PHI)
Y = (R + r*np.cos(THETA))*np.sin(PHI)
Z = r * np.sin(0.5*THETA)

ax.view_init(60,30)
ax.plot_wireframe(X,Y,Z)

# %% [markdown]
# ## 2. Miscellaneous advanced topics
#
# ### Keyword arguments
#
# We can define functions with keyword arguments such as :

# %%
def fun(a,b,add=True):
    if add == True:
        return a + b
    else:
        return a*b

# %%
fun(1,2)
# Out:
# 3

# %% [markdown]
# In this example, `add` input parameter is called a keyword argument and it has a defult value `True`.
#
# The first 2 input parameters `a` and `b` are called positional arguments. This means that the order in which values are input into `fun` determine which is `a` and which `b`. In other words, in the example above, when we call `fun(1,2)` the function `fun` knows that `a=1` and `b=2` since that's the order they came.

# %%
fun(3,5,add=False)
# Out:
# 15

# %%
plt.plot?

# %% [markdown]
# ### List comprehensions with if/else

# %% [markdown]
# #### Example
#
# Let's make a list of integers from 1 to 100 which are either multiples of 3 or 7.

# %%
a = [n for n in range(1,41) if n % 3 == 0 or n % 7 ==0]

# %%
a
# Out:
# [3, 6, 7, 9, 12, 14, 15, 18, 21, 24, 27, 28, 30, 33, 35, 36, 39]

# %%
n = 100
div = [d for d in range(1,n+1) if n % d ==0]

# %%
div
# Out:
# [1, 2, 4, 5, 10, 20, 25, 50, 100]
